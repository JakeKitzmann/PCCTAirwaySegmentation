# %%
import itk
import numpy as np
import matplotlib.pyplot as plt

# %%
fain_segmentation = itk.imread(r'../AnalyzeAirwaySeg/testdata/Fain.nii.gz')
sn_image = itk.imread(r'../AnalyzeAirwaySeg/testdata/Sn.nii.gz')

# %%
def show(image, dims=None):
    if dims == None: 
        dims = [x//2 for x in image.GetLargestPossibleRegion.GetSize()]
    image_arr = itk.
